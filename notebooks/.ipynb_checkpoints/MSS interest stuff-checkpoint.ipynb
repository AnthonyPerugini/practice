Amount: zero dollars and one cent+ $0.01

FEB 28 2017
Credit Interest
Amount: zero dollars and one cent+ $0.01'''.strip()

# %%
summ = 0
for ss in s.split('\n\n'):
    if ss.split()[2] == '2020':
#         print(ss)
        summ += float(ss.split()[-1][1:])
print(summ)
# Out:
# 7.590000000000002

# %%
bc = '''portfolio,trade id,product,side,created at,size,size unit,price,fee,total,price/fee/total unit
default,117031873,BTC-USD,SELL,2020-12-30T23:03:57.211Z,0.10200000,BTC,28735,14.65485,2916.31515,USD
default,117031874,BTC-USD,SELL,2020-12-30T23:03:57.220Z,0.05000000,BTC,28735,7.18375,1429.56625,USD
default,117031875,BTC-USD,SELL,2020-12-30T23:03:57.237Z,0.15000000,BTC,28735,21.55125,4288.69875,USD
default,117031876,BTC-USD,SELL,2020-12-30T23:03:57.241Z,0.10000000,BTC,28735,14.3675,2859.1325,USD
default,117031877,BTC-USD,SELL,2020-12-30T23:03:57.251Z,0.15000000,BTC,28735,21.55125,4288.69875,USD
default,117031878,BTC-USD,SELL,2020-12-30T23:03:57.266Z,0.05000000,BTC,28735,7.18375,1429.56625,USD
default,117031879,BTC-USD,SELL,2020-12-30T23:03:57.271Z,0.05000000,BTC,28735,7.18375,1429.56625,USD
default,117031880,BTC-USD,SELL,2020-12-30T23:03:57.283Z,0.40000000,BTC,28735,57.47,11436.53,USD
default,117031881,BTC-USD,SELL,2020-12-30T23:03:57.302Z,0.10000000,BTC,28735,14.3675,2859.1325,USD
default,117031882,BTC-USD,SELL,2020-12-30T23:03:57.341Z,0.00865690,BTC,28735,1.2437801075,247.5122413925,USD
default,117031883,BTC-USD,SELL,2020-12-30T23:03:57.386Z,0.08900000,BTC,28735,12.787075,2544.627925,USD
default,117031884,BTC-USD,SELL,2020-12-30T23:03:57.707Z,0.00034310,BTC,28735,0.0492948925,9.8096836075,USD
default,117032796,BTC-USD,BUY,2020-12-30T23:09:56.256Z,1.13842642,BTC,28750,163.648797875,-32893.408372875,USD
default,117032798,BTC-USD,BUY,2020-12-30T23:09:56.766Z,0.09800000,BTC,28750,14.0875,-2831.5875,USD
default,117032800,BTC-USD,BUY,2020-12-30T23:09:57.440Z,0.00049008,BTC,28750,0.070449,-14.160249,USD'''.strip()

# %%
bc.split('\n')
# Out:
# ['portfolio,trade id,product,side,created at,size,size unit,price,fee,total,price/fee/total unit',
#  'default,117031873,BTC-USD,SELL,2020-12-30T23:03:57.211Z,0.10200000,BTC,28735,14.65485,2916.31515,USD',
#  'default,117031874,BTC-USD,SELL,2020-12-30T23:03:57.220Z,0.05000000,BTC,28735,7.18375,1429.56625,USD',
#  'default,117031875,BTC-USD,SELL,2020-12-30T23:03:57.237Z,0.15000000,BTC,28735,21.55125,4288.69875,USD',
#  'default,117031876,BTC-USD,SELL,2020-12-30T23:03:57.241Z,0.10000000,BTC,28735,14.3675,2859.1325,USD',
#  'default,117031877,BTC-USD,SELL,2020-12-30T23:03:57.251Z,0.15000000,BTC,28735,21.55125,4288.69875,USD',
#  'default,117031878,BTC-USD,SELL,2020-12-30T23:03:57.266Z,0.05000000,BTC,28735,7.18375,1429.56625,USD',
#  'default,117031879,BTC-USD,SELL,2020-12-30T23:03:57.271Z,0.05000000,BTC,28735,7.18375,1429.56625,USD',
#  'default,117031880,BTC-USD,SELL,2020-12-30T23:03:57.283Z,0.40000000,BTC,28735,57.47,11436.53,USD',
# ...

# %%
sold = bought = fee = 0
for ele in bc.split('\n')[1:]:
    items = ele.split(',')
    fee += float(items[-3])
    if items[3] == 'SELL':
        bought += float(items[-2])
    if items[3] == 'BUY':
        sold -= float(items[-2])
        
print(round(sold,2), round(bought,2), round(fee,2))
# Out:
# 35739.16 35739.16 357.4
